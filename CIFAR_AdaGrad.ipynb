# %%
# TEAM UNI:  Sagat Damani ssd2144 Eric Jhonson  efj2106   Aman Shankar as5171
import tensorflow as tf
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import scipy.misc
import glob
import sys

# %%
# Helper functions, DO NOT modify this

def get_img_array(path):
    """
    Given path of image, returns it's numpy array
    """
    return scipy.misc.imread(path)

def get_files(folder):
    """
    Given path to folder, returns list of files in it
    """
    filenames = [file for file in glob.glob(folder+'*/*')]
    filenames.sort()
    return filenames

def get_label(filepath, label2id):
    """
    Files are assumed to be labeled as: /path/to/file/999_frog.png
    Returns label for a filepath
    """
    tokens = filepath.split('/')
    label = tokens[-1].split('_')[1][:-4]
    if label in label2id:
        return label2id[label]
    else:
        sys.exit("Invalid label: " + label)

# Functions to load data, DO NOT change these

def get_labels(folder, label2id):
    """
    Returns vector of labels extracted from filenames of all files in folder
    :param folder: path to data folder
    :param label2id: mapping of text labels to numeric ids. (Eg: automobile -> 0)
    """
    files = get_files(folder)
    y = []
    for f in files:
        y.append(get_label(f,label2id))
    return np.array(y)

def one_hot(y, num_classes=10):
    """
    Converts each label index in y to vector with one_hot encoding
    """
    y_one_hot = np.zeros((y.shape[0], num_classes))
    y_one_hot[y] = 1
    return y_one_hot.T

def get_label_mapping(label_file):
    """
    Returns mappings of label to index and index to label
    The input file has list of labels, each on a separate line.
    """
    with open(label_file, 'r') as f:
        id2label = f.readlines()
        id2label = [l.strip() for l in id2label]
    label2id = {}
    count = 0
    for label in id2label:
        label2id[label] = count
        count += 1
    return id2label, label2id

def get_images(folder):
    """
    returns numpy array of all samples in folder
    each column is a sample resized to 30x30 and flattened
    """
    files = get_files(folder)
    images = []
    count = 0
    
    for f in files:
        count += 1
        if count % 10000 == 0:
            print("Loaded {}/{}".format(count,len(files)))
        img_arr = get_img_array(f)
        img_arr = img_arr.flatten() / 255.0
        images.append(img_arr)
    X = np.column_stack(images)

    return X

def get_train_data(data_root_path):
    """
    Return X and y
    """
    train_data_path = data_root_path + 'train'
    id2label, label2id = get_label_mapping(data_root_path+'labels.txt')
    print(label2id)
    X = get_images(train_data_path)
    y = get_labels(train_data_path, label2id)
    return X, y

def save_predictions(filename, y):
    """
    Dumps y into .npy file
    """
    np.save(filename, y)

# %%
# Load the data
data_root_path = './cifar10-hw1/'
X_train_orig, y_train_orig = get_train_data(data_root_path) # this may take a few minutes
X_test_orig = get_images(data_root_path + 'test')
print('Data loading done')
# Out:
# {'horse': 7, 'automobile': 1, 'deer': 4, 'dog': 5, 'frog': 6, 'cat': 3, 'truck': 9, 'ship': 8, 'airplane': 0, 'bird': 2}
# Loaded 10000/50000
# Loaded 20000/50000
# Loaded 30000/50000
# Loaded 40000/50000
# Loaded 50000/50000
# Loaded 10000/10000
# Data loading done

# %%
#Perform train-validation split (90-10)
X_train, y_train = X_train_orig, y_train_orig
indices = np.random.permutation(X_train.shape[1])
split_point = int(len(indices)* 0.9)
print(split_point)
training_indices, validation_indices = indices[:split_point], indices[split_point:]

X_train, X_validation = X_train[: , training_indices], X_train[:, validation_indices]
y_train, y_validation = y_train[training_indices], y_train[validation_indices]
print(X_train.shape)
print(X_validation.shape)
# Out:
# 45000
# (3072, 45000)
# (3072, 5000)

# %%
X_train = np.transpose(X_train).astype("float32")
y_train = y_train.astype("float32")
print(X_train.shape)
print(y_train.shape)

X_validation = np.transpose(X_validation).astype("float32")
y_validation = y_validation.astype("float32")
# Out:
# (45000, 3072)
# (45000,)

# %%
def cnn_model_fmine(features, labels, mode):
  """Model function for CNN."""
  # Input Layer
  input_layer = tf.reshape(features["x"], [-1, 32, 32, 3])

  conv1 = tf.layers.conv2d(
      inputs=input_layer,
      filters=32,
      kernel_size=[3, 3],
      padding="same",
      activation=tf.nn.relu, name='conv1')

  kernel = tf.get_collection(tf.GraphKeys.VARIABLES, 'conv1/kernel')[0]
  tf.summary.histogram("conv_layer1",kernel)
  conv1 = tf.layers.batch_normalization(conv1)
  drop1 = tf.layers.dropout(inputs=conv1, rate=0.2, training=mode == tf.estimator.ModeKeys.TRAIN)
  # Pooling Layer #1
  pool1 = tf.layers.max_pooling2d(inputs=drop1, pool_size=[2, 2], strides=2)

  # Convolutional Layer #2 and Pooling Layer #2
  conv2 = tf.layers.conv2d(
      inputs=pool1,
      filters=64,
      kernel_size=[3, 3],
      padding="same",
      activation=tf.nn.relu, name='conv2')

  kernel = tf.get_collection(tf.GraphKeys.VARIABLES, 'conv2/kernel')[0]
  tf.summary.histogram("conv_layer2",kernel)
    
  conv2 = tf.layers.batch_normalization(conv2)
  drop2 = tf.layers.dropout(inputs=conv2, rate=0.3, training=mode == tf.estimator.ModeKeys.TRAIN)
  pool2 = tf.layers.max_pooling2d(inputs=drop2, pool_size=[2, 2], strides=2)

  print(conv2.get_shape().as_list())
  print(pool2.get_shape().as_list())

  # Convolutional Layer #3 and Pooling Layer #3
  conv3 = tf.layers.conv2d(
      inputs=pool2,
      filters=128,
      kernel_size=[3, 3],
      padding="same",
      activation=tf.nn.relu, name="conv3")
    
  kernel = tf.get_collection(tf.GraphKeys.VARIABLES, 'conv3/kernel')[0]
  tf.summary.histogram("conv_layer3",kernel)

  conv3 = tf.layers.batch_normalization(conv3)
  drop3 = tf.layers.dropout(inputs=conv3, rate=0.4, training=mode == tf.estimator.ModeKeys.TRAIN)
  pool3 = tf.layers.max_pooling2d(inputs=drop3, pool_size=[2, 2], strides=2)

  # Dense Layer
  pool3_flat = tf.reshape(pool3, [-1, 4 * 4 * 128])
  dense = tf.layers.dense(inputs=pool3_flat, units=1024, activation=tf.nn.relu, name="dense")

  kernel = tf.get_collection(tf.GraphKeys.VARIABLES, 'dense/kernel')[0]
  tf.summary.histogram("dense_layer1",kernel)

  drop4 = tf.layers.dropout(inputs=dense, rate=0.3, training=mode == tf.estimator.ModeKeys.TRAIN)

  # Logits Layer
  logits = tf.layers.dense(inputs=drop4, units=10)

  predictions = {
      # Generate predictions (for PREDICT and EVAL mode)
      "classes": tf.argmax(input=logits, axis=1),
      # Add `softmax_tensor` to the graph. It is used for PREDICT and by the
      # `logging_hook`.
      "probabilities": tf.nn.softmax(logits, name="softmax_tensor")
  }

  if mode == tf.estimator.ModeKeys.PREDICT:
    return tf.estimator.EstimatorSpec(mode=mode, predictions=tf.nn.softmax(logits, name="softmax_tensor"))

  # Calculate Loss (for both TRAIN and EVAL modes)
  onehot_labels = tf.one_hot(indices=tf.cast(labels, tf.int32), depth=10)
  loss = tf.losses.softmax_cross_entropy(
      onehot_labels=onehot_labels, logits=logits)

  # Configure the Training Op (for TRAIN mode)
  if mode == tf.estimator.ModeKeys.TRAIN:
    optimizer = tf.train.AdagradOptimizer(learning_rate=0.01)
    train_op = optimizer.minimize(
        loss=loss,
        global_step=tf.train.get_global_step())
    return tf.estimator.EstimatorSpec(mode=mode, loss=loss, train_op=train_op)

  # Add evaluation metrics (for EVAL mode)
  eval_metric_ops = {
      "accuracy": tf.metrics.accuracy(
          labels=labels, predictions=predictions["classes"])}
  return tf.estimator.EstimatorSpec(
      mode=mode, loss=loss, eval_metric_ops=eval_metric_ops)# Train the model

# %%
# Train the model
print(X_train.shape)
print(y_train.shape)

my_classifier = tf.estimator.Estimator(
    model_fn=cnn_model_fmine, model_dir="/tmp/new_best_1")
train_input_fn = tf.estimator.inputs.numpy_input_fn(
    x={"x": X_train},
    y=y_train,
    batch_size=100,
    num_epochs=None,
    shuffle=True)
my_classifier.train(
    input_fn=train_input_fn,
    steps=40000)
# Out:
# (45000, 3072)
# (45000,)
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_tf_random_seed': 1, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_save_checkpoints_steps': None, '_model_dir': '/tmp/new_best_1', '_save_summary_steps': 100}
# WARNING:tensorflow:VARIABLES collection name is deprecated, please use GLOBAL_VARIABLES instead; VARIABLES will be removed after 2017-03-02.
# WARNING:tensorflow:VARIABLES collection name is deprecated, please use GLOBAL_VARIABLES instead; VARIABLES will be removed after 2017-03-02.
# [100, 16, 16, 64]
# [100, 8, 8, 64]
# WARNING:tensorflow:VARIABLES collection name is deprecated, please use GLOBAL_VARIABLES instead; VARIABLES will be removed after 2017-03-02.
# WARNING:tensorflow:VARIABLES collection name is deprecated, please use GLOBAL_VARIABLES instead; VARIABLES will be removed after 2017-03-02.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into /tmp/new_best_1/model.ckpt.
# INFO:tensorflow:loss = 2.32993, step = 1
# INFO:tensorflow:global_step/sec: 39.219
# INFO:tensorflow:loss = 2.09719, step = 101 (2.551 sec)
# INFO:tensorflow:global_step/sec: 41.8739
# INFO:tensorflow:loss = 1.99161, step = 201 (2.388 sec)
# INFO:tensorflow:global_step/sec: 41.7414
# INFO:tensorflow:loss = 1.93751, step = 301 (2.396 sec)
# INFO:tensorflow:global_step/sec: 41.7589
# INFO:tensorflow:loss = 1.64375, step = 401 (2.395 sec)
# INFO:tensorflow:global_step/sec: 41.7843
# INFO:tensorflow:loss = 1.68879, step = 501 (2.393 sec)
# INFO:tensorflow:global_step/sec: 41.8232
# INFO:tensorflow:loss = 1.91607, step = 601 (2.391 sec)
# INFO:tensorflow:global_step/sec: 41.7129
# INFO:tensorflow:loss = 1.64535, step = 701 (2.397 sec)
# INFO:tensorflow:global_step/sec: 41.7779
# INFO:tensorflow:loss = 1.68434, step = 801 (2.394 sec)
# INFO:tensorflow:global_step/sec: 41.789
# INFO:tensorflow:loss = 1.40166, step = 901 (2.393 sec)
# INFO:tensorflow:global_step/sec: 41.8397
# INFO:tensorflow:loss = 1.71212, step = 1001 (2.390 sec)
# INFO:tensorflow:global_step/sec: 41.7995
# INFO:tensorflow:loss = 1.55325, step = 1101 (2.393 sec)
# INFO:tensorflow:global_step/sec: 41.8072
# INFO:tensorflow:loss = 1.48968, step = 1201 (2.392 sec)
# INFO:tensorflow:global_step/sec: 41.7502
# INFO:tensorflow:loss = 1.35776, step = 1301 (2.395 sec)
# INFO:tensorflow:global_step/sec: 41.8117
# INFO:tensorflow:loss = 1.39408, step = 1401 (2.392 sec)
# INFO:tensorflow:global_step/sec: 41.8931
# INFO:tensorflow:loss = 1.33748, step = 1501 (2.387 sec)
# INFO:tensorflow:global_step/sec: 41.8237
# INFO:tensorflow:loss = 1.38555, step = 1601 (2.391 sec)
# INFO:tensorflow:global_step/sec: 41.8492
# INFO:tensorflow:loss = 1.36677, step = 1701 (2.390 sec)
# INFO:tensorflow:global_step/sec: 41.8941
# INFO:tensorflow:loss = 1.31602, step = 1801 (2.387 sec)
# INFO:tensorflow:global_step/sec: 41.7884
# INFO:tensorflow:loss = 1.5839, step = 1901 (2.393 sec)
# INFO:tensorflow:global_step/sec: 41.7293
# INFO:tensorflow:loss = 1.26138, step = 2001 (2.397 sec)
# INFO:tensorflow:global_step/sec: 41.7875
# INFO:tensorflow:loss = 1.43578, step = 2101 (2.393 sec)
# INFO:tensorflow:global_step/sec: 41.8166
# INFO:tensorflow:loss = 1.47149, step = 2201 (2.391 sec)
# INFO:tensorflow:global_step/sec: 41.9145
# INFO:tensorflow:loss = 1.42771, step = 2301 (2.386 sec)
# INFO:tensorflow:global_step/sec: 41.7724
# INFO:tensorflow:loss = 1.1406, step = 2401 (2.394 sec)
# INFO:tensorflow:global_step/sec: 41.7594
# INFO:tensorflow:loss = 1.26123, step = 2501 (2.395 sec)
# INFO:tensorflow:global_step/sec: 41.8284
# INFO:tensorflow:loss = 1.26748, step = 2601 (2.391 sec)
# INFO:tensorflow:global_step/sec: 41.8024
# INFO:tensorflow:loss = 1.24989, step = 2701 (2.393 sec)
# INFO:tensorflow:global_step/sec: 41.7202
# INFO:tensorflow:loss = 1.4252, step = 2801 (2.396 sec)
# INFO:tensorflow:global_step/sec: 41.754
# INFO:tensorflow:loss = 1.10964, step = 2901 (2.395 sec)
# INFO:tensorflow:global_step/sec: 41.8132
# INFO:tensorflow:loss = 1.4064, step = 3001 (2.392 sec)
# INFO:tensorflow:global_step/sec: 41.8447
# INFO:tensorflow:loss = 1.16149, step = 3101 (2.390 sec)
# INFO:tensorflow:global_step/sec: 41.6531
# INFO:tensorflow:loss = 1.24097, step = 3201 (2.400 sec)
# INFO:tensorflow:global_step/sec: 41.866
# INFO:tensorflow:loss = 1.13727, step = 3301 (2.389 sec)
# INFO:tensorflow:global_step/sec: 41.7831
# INFO:tensorflow:loss = 1.04302, step = 3401 (2.394 sec)
# INFO:tensorflow:global_step/sec: 41.6641
# INFO:tensorflow:loss = 1.11329, step = 3501 (2.400 sec)
# INFO:tensorflow:global_step/sec: 41.8396
# INFO:tensorflow:loss = 1.25505, step = 3601 (2.390 sec)
# INFO:tensorflow:global_step/sec: 41.8188
# INFO:tensorflow:loss = 1.10978, step = 3701 (2.391 sec)
# INFO:tensorflow:global_step/sec: 41.6937
# INFO:tensorflow:loss = 1.04011, step = 3801 (2.398 sec)
# INFO:tensorflow:global_step/sec: 41.7214
# INFO:tensorflow:loss = 1.19519, step = 3901 (2.397 sec)
# INFO:tensorflow:global_step/sec: 41.6266
# INFO:tensorflow:loss = 1.18167, step = 4001 (2.402 sec)
# INFO:tensorflow:global_step/sec: 41.7469
# INFO:tensorflow:loss = 0.88599, step = 4101 (2.395 sec)
# INFO:tensorflow:global_step/sec: 41.8359
# INFO:tensorflow:loss = 1.22111, step = 4201 (2.390 sec)
# INFO:tensorflow:global_step/sec: 41.7792
# INFO:tensorflow:loss = 0.981434, step = 4301 (2.394 sec)
# INFO:tensorflow:global_step/sec: 41.7434
# INFO:tensorflow:loss = 1.1314, step = 4401 (2.395 sec)
# INFO:tensorflow:global_step/sec: 41.7047
# INFO:tensorflow:loss = 1.05313, step = 4501 (2.398 sec)
# INFO:tensorflow:global_step/sec: 41.6778
# INFO:tensorflow:loss = 1.0264, step = 4601 (2.399 sec)
# INFO:tensorflow:global_step/sec: 41.4452
# INFO:tensorflow:loss = 1.17073, step = 4701 (2.413 sec)
# INFO:tensorflow:global_step/sec: 41.1596
# INFO:tensorflow:loss = 1.00395, step = 4801 (2.429 sec)
# INFO:tensorflow:global_step/sec: 41.671
# INFO:tensorflow:loss = 0.996493, step = 4901 (2.400 sec)
# INFO:tensorflow:global_step/sec: 41.778
# INFO:tensorflow:loss = 0.817398, step = 5001 (2.393 sec)
# INFO:tensorflow:global_step/sec: 41.7982
# INFO:tensorflow:loss = 0.922496, step = 5101 (2.392 sec)
# INFO:tensorflow:global_step/sec: 41.7782
# INFO:tensorflow:loss = 0.98393, step = 5201 (2.394 sec)
# INFO:tensorflow:global_step/sec: 41.6548
# INFO:tensorflow:loss = 0.924702, step = 5301 (2.401 sec)
# INFO:tensorflow:global_step/sec: 41.7958
# INFO:tensorflow:loss = 0.873059, step = 5401 (2.393 sec)
# INFO:tensorflow:global_step/sec: 41.8184
# INFO:tensorflow:loss = 0.950998, step = 5501 (2.391 sec)
# INFO:tensorflow:global_step/sec: 41.7354
# INFO:tensorflow:loss = 1.26622, step = 5601 (2.396 sec)
# INFO:tensorflow:global_step/sec: 41.731
# INFO:tensorflow:loss = 0.838474, step = 5701 (2.396 sec)
# INFO:tensorflow:global_step/sec: 41.5776
# INFO:tensorflow:loss = 1.02151, step = 5801 (2.405 sec)
# INFO:tensorflow:global_step/sec: 41.63
# INFO:tensorflow:loss = 1.00322, step = 5901 (2.402 sec)
# INFO:tensorflow:global_step/sec: 41.731
# INFO:tensorflow:loss = 0.994104, step = 6001 (2.396 sec)
# INFO:tensorflow:global_step/sec: 41.8475
# INFO:tensorflow:loss = 0.967602, step = 6101 (2.389 sec)
# INFO:tensorflow:global_step/sec: 41.7433
# INFO:tensorflow:loss = 0.97628, step = 6201 (2.396 sec)
# INFO:tensorflow:global_step/sec: 41.7651
# INFO:tensorflow:loss = 0.844615, step = 6301 (2.394 sec)
# INFO:tensorflow:global_step/sec: 41.81
# INFO:tensorflow:loss = 0.947686, step = 6401 (2.391 sec)
# INFO:tensorflow:global_step/sec: 41.8363
# INFO:tensorflow:loss = 0.885606, step = 6501 (2.390 sec)
# INFO:tensorflow:global_step/sec: 41.7511
# INFO:tensorflow:loss = 0.804238, step = 6601 (2.395 sec)
# INFO:tensorflow:global_step/sec: 41.6965
# INFO:tensorflow:loss = 0.928941, step = 6701 (2.399 sec)
# INFO:tensorflow:global_step/sec: 41.8543
# INFO:tensorflow:loss = 0.732484, step = 6801 (2.389 sec)
# INFO:tensorflow:global_step/sec: 41.6641
# INFO:tensorflow:loss = 0.795834, step = 6901 (2.400 sec)
# INFO:tensorflow:global_step/sec: 41.753
# INFO:tensorflow:loss = 0.886347, step = 7001 (2.395 sec)
# INFO:tensorflow:global_step/sec: 41.7015
# INFO:tensorflow:loss = 0.929677, step = 7101 (2.398 sec)
# INFO:tensorflow:global_step/sec: 41.7197
# INFO:tensorflow:loss = 0.93632, step = 7201 (2.397 sec)
# INFO:tensorflow:global_step/sec: 41.7577
# INFO:tensorflow:loss = 0.922553, step = 7301 (2.394 sec)
# INFO:tensorflow:global_step/sec: 41.7758
# INFO:tensorflow:loss = 0.815243, step = 7401 (2.394 sec)
# INFO:tensorflow:global_step/sec: 41.7312
# INFO:tensorflow:loss = 1.00426, step = 7501 (2.396 sec)
# INFO:tensorflow:global_step/sec: 41.7196
# INFO:tensorflow:loss = 0.819568, step = 7601 (2.397 sec)
# INFO:tensorflow:global_step/sec: 41.7876
# INFO:tensorflow:loss = 0.738948, step = 7701 (2.393 sec)
# INFO:tensorflow:global_step/sec: 41.7299
# INFO:tensorflow:loss = 0.835889, step = 7801 (2.396 sec)
# INFO:tensorflow:global_step/sec: 41.7469
# INFO:tensorflow:loss = 0.682973, step = 7901 (2.395 sec)
# INFO:tensorflow:global_step/sec: 41.7085
# INFO:tensorflow:loss = 0.963663, step = 8001 (2.398 sec)
# INFO:tensorflow:global_step/sec: 41.7706
# INFO:tensorflow:loss = 0.868932, step = 8101 (2.394 sec)
# INFO:tensorflow:global_step/sec: 41.7147
# INFO:tensorflow:loss = 0.807197, step = 8201 (2.398 sec)
# INFO:tensorflow:global_step/sec: 41.7184
# INFO:tensorflow:loss = 0.728008, step = 8301 (2.397 sec)
# INFO:tensorflow:global_step/sec: 41.755
# INFO:tensorflow:loss = 0.992043, step = 8401 (2.395 sec)
# INFO:tensorflow:global_step/sec: 41.7904
# INFO:tensorflow:loss = 0.769873, step = 8501 (2.393 sec)
# INFO:tensorflow:global_step/sec: 41.7609
# INFO:tensorflow:loss = 0.768694, step = 8601 (2.395 sec)
# INFO:tensorflow:global_step/sec: 41.7025
# INFO:tensorflow:loss = 0.938793, step = 8701 (2.398 sec)
# INFO:tensorflow:global_step/sec: 41.7772
# INFO:tensorflow:loss = 0.805696, step = 8801 (2.393 sec)
# INFO:tensorflow:global_step/sec: 41.7154
# INFO:tensorflow:loss = 0.913755, step = 8901 (2.397 sec)
# INFO:tensorflow:global_step/sec: 41.8166
# INFO:tensorflow:loss = 0.732767, step = 9001 (2.391 sec)
# INFO:tensorflow:global_step/sec: 41.8257
# INFO:tensorflow:loss = 0.771031, step = 9101 (2.391 sec)
# INFO:tensorflow:global_step/sec: 41.6528
# INFO:tensorflow:loss = 0.808456, step = 9201 (2.401 sec)
# INFO:tensorflow:global_step/sec: 41.7202
# INFO:tensorflow:loss = 0.884003, step = 9301 (2.397 sec)
# INFO:tensorflow:global_step/sec: 41.6603
# INFO:tensorflow:loss = 0.800381, step = 9401 (2.400 sec)
# INFO:tensorflow:global_step/sec: 41.8153
# INFO:tensorflow:loss = 0.933862, step = 9501 (2.391 sec)
# INFO:tensorflow:global_step/sec: 41.754
# INFO:tensorflow:loss = 0.607558, step = 9601 (2.395 sec)
# INFO:tensorflow:global_step/sec: 41.8351
# INFO:tensorflow:loss = 0.868752, step = 9701 (2.390 sec)
# INFO:tensorflow:global_step/sec: 41.6907
# INFO:tensorflow:loss = 0.997057, step = 9801 (2.399 sec)
# INFO:tensorflow:global_step/sec: 41.7298
# INFO:tensorflow:loss = 0.695252, step = 9901 (2.396 sec)
# INFO:tensorflow:global_step/sec: 41.7098
# INFO:tensorflow:loss = 0.704702, step = 10001 (2.398 sec)
# INFO:tensorflow:global_step/sec: 41.838
# INFO:tensorflow:loss = 0.810389, step = 10101 (2.390 sec)
# INFO:tensorflow:global_step/sec: 41.7656
# INFO:tensorflow:loss = 0.776017, step = 10201 (2.394 sec)
# INFO:tensorflow:global_step/sec: 41.8572
# INFO:tensorflow:loss = 0.714525, step = 10301 (2.389 sec)
# INFO:tensorflow:global_step/sec: 41.7969
# INFO:tensorflow:loss = 0.768244, step = 10401 (2.393 sec)
# INFO:tensorflow:global_step/sec: 41.7254
# INFO:tensorflow:loss = 0.675142, step = 10501 (2.397 sec)
# INFO:tensorflow:global_step/sec: 41.7341
# INFO:tensorflow:loss = 0.812601, step = 10601 (2.396 sec)
# INFO:tensorflow:global_step/sec: 41.7813
# INFO:tensorflow:loss = 0.695806, step = 10701 (2.394 sec)
# INFO:tensorflow:global_step/sec: 41.7238
# INFO:tensorflow:loss = 0.844316, step = 10801 (2.396 sec)
# INFO:tensorflow:global_step/sec: 41.7514
# INFO:tensorflow:loss = 0.886796, step = 10901 (2.395 sec)
# INFO:tensorflow:global_step/sec: 41.7874
# INFO:tensorflow:loss = 0.707519, step = 11001 (2.393 sec)
# INFO:tensorflow:global_step/sec: 41.7615
# INFO:tensorflow:loss = 0.802431, step = 11101 (2.395 sec)
# INFO:tensorflow:global_step/sec: 41.7648
# INFO:tensorflow:loss = 0.521893, step = 11201 (2.394 sec)
# INFO:tensorflow:global_step/sec: 41.7965
# INFO:tensorflow:loss = 0.591523, step = 11301 (2.392 sec)
# INFO:tensorflow:global_step/sec: 41.7355
# INFO:tensorflow:loss = 0.674871, step = 11401 (2.396 sec)
# INFO:tensorflow:global_step/sec: 41.6247
# INFO:tensorflow:loss = 0.690748, step = 11501 (2.402 sec)
# INFO:tensorflow:global_step/sec: 41.5612
# INFO:tensorflow:loss = 0.725819, step = 11601 (2.407 sec)
# INFO:tensorflow:global_step/sec: 41.7188
# INFO:tensorflow:loss = 0.577153, step = 11701 (2.396 sec)
# INFO:tensorflow:global_step/sec: 41.7948
# INFO:tensorflow:loss = 0.606046, step = 11801 (2.393 sec)
# INFO:tensorflow:global_step/sec: 41.6863
# INFO:tensorflow:loss = 0.499856, step = 11901 (2.399 sec)
# INFO:tensorflow:global_step/sec: 41.8618
# INFO:tensorflow:loss = 0.565498, step = 12001 (2.389 sec)
# INFO:tensorflow:global_step/sec: 41.7487
# INFO:tensorflow:loss = 0.876565, step = 12101 (2.395 sec)
# INFO:tensorflow:global_step/sec: 41.7115
# INFO:tensorflow:loss = 0.695713, step = 12201 (2.397 sec)
# INFO:tensorflow:global_step/sec: 41.6714
# INFO:tensorflow:loss = 0.674609, step = 12301 (2.400 sec)
# INFO:tensorflow:global_step/sec: 41.7435
# INFO:tensorflow:loss = 0.614915, step = 12401 (2.395 sec)
# INFO:tensorflow:global_step/sec: 41.7476
# INFO:tensorflow:loss = 0.553085, step = 12501 (2.395 sec)
# INFO:tensorflow:global_step/sec: 41.71
# INFO:tensorflow:loss = 0.685281, step = 12601 (2.398 sec)
# INFO:tensorflow:global_step/sec: 41.7057
# INFO:tensorflow:loss = 0.707028, step = 12701 (2.398 sec)
# INFO:tensorflow:global_step/sec: 41.7113
# INFO:tensorflow:loss = 0.887977, step = 12801 (2.397 sec)
# INFO:tensorflow:global_step/sec: 41.7667
# INFO:tensorflow:loss = 0.625476, step = 12901 (2.395 sec)
# INFO:tensorflow:global_step/sec: 41.808
# INFO:tensorflow:loss = 0.645087, step = 13001 (2.392 sec)
# INFO:tensorflow:global_step/sec: 41.7601
# INFO:tensorflow:loss = 0.688981, step = 13101 (2.395 sec)
# INFO:tensorflow:global_step/sec: 41.7421
# INFO:tensorflow:loss = 0.744927, step = 13201 (2.396 sec)
# INFO:tensorflow:global_step/sec: 41.7864
# INFO:tensorflow:loss = 0.68977, step = 13301 (2.393 sec)
# INFO:tensorflow:global_step/sec: 41.6786
# INFO:tensorflow:loss = 0.890262, step = 13401 (2.399 sec)
# INFO:tensorflow:global_step/sec: 41.6801
# INFO:tensorflow:loss = 0.769401, step = 13501 (2.399 sec)
# INFO:tensorflow:global_step/sec: 41.6897
# INFO:tensorflow:loss = 0.617383, step = 13601 (2.399 sec)
# INFO:tensorflow:global_step/sec: 41.7807
# INFO:tensorflow:loss = 0.474007, step = 13701 (2.394 sec)
# INFO:tensorflow:global_step/sec: 41.7476
# INFO:tensorflow:loss = 0.775819, step = 13801 (2.395 sec)
# INFO:tensorflow:global_step/sec: 41.6931
# INFO:tensorflow:loss = 0.623437, step = 13901 (2.399 sec)
# INFO:tensorflow:global_step/sec: 41.6149
# INFO:tensorflow:loss = 0.545195, step = 14001 (2.403 sec)
# INFO:tensorflow:global_step/sec: 41.7839
# INFO:tensorflow:loss = 0.924, step = 14101 (2.393 sec)
# INFO:tensorflow:global_step/sec: 41.7556
# INFO:tensorflow:loss = 0.565931, step = 14201 (2.395 sec)
# INFO:tensorflow:global_step/sec: 41.6983
# INFO:tensorflow:loss = 0.635953, step = 14301 (2.398 sec)
# INFO:tensorflow:global_step/sec: 41.779
# INFO:tensorflow:loss = 0.456898, step = 14401 (2.393 sec)
# INFO:tensorflow:global_step/sec: 41.6978
# INFO:tensorflow:loss = 0.509722, step = 14501 (2.398 sec)
# INFO:tensorflow:global_step/sec: 41.6161
# INFO:tensorflow:loss = 0.525478, step = 14601 (2.403 sec)
# INFO:tensorflow:global_step/sec: 41.7623
# INFO:tensorflow:loss = 0.587285, step = 14701 (2.395 sec)
# INFO:tensorflow:global_step/sec: 41.6005
# INFO:tensorflow:loss = 0.681012, step = 14801 (2.404 sec)
# INFO:tensorflow:global_step/sec: 41.7927
# INFO:tensorflow:loss = 0.641761, step = 14901 (2.393 sec)
# INFO:tensorflow:global_step/sec: 41.7244
# INFO:tensorflow:loss = 0.632037, step = 15001 (2.397 sec)
# INFO:tensorflow:global_step/sec: 41.7283
# INFO:tensorflow:loss = 0.514775, step = 15101 (2.396 sec)
# INFO:tensorflow:global_step/sec: 41.8071
# INFO:tensorflow:loss = 0.566092, step = 15201 (2.392 sec)
# INFO:tensorflow:global_step/sec: 41.7648
# INFO:tensorflow:loss = 0.679945, step = 15301 (2.394 sec)
# INFO:tensorflow:global_step/sec: 41.6842
# INFO:tensorflow:loss = 0.690862, step = 15401 (2.399 sec)
# INFO:tensorflow:global_step/sec: 41.7072
# INFO:tensorflow:loss = 0.577914, step = 15501 (2.398 sec)
# INFO:tensorflow:global_step/sec: 41.6681
# INFO:tensorflow:loss = 0.583122, step = 15601 (2.400 sec)
# INFO:tensorflow:global_step/sec: 41.7261
# INFO:tensorflow:loss = 0.548582, step = 15701 (2.397 sec)
# INFO:tensorflow:global_step/sec: 41.7081
# INFO:tensorflow:loss = 0.634515, step = 15801 (2.397 sec)
# INFO:tensorflow:global_step/sec: 41.7609
# INFO:tensorflow:loss = 0.507953, step = 15901 (2.395 sec)
# INFO:tensorflow:global_step/sec: 41.8208
# INFO:tensorflow:loss = 0.58913, step = 16001 (2.391 sec)
# INFO:tensorflow:global_step/sec: 41.83
# INFO:tensorflow:loss = 0.760777, step = 16101 (2.391 sec)
# INFO:tensorflow:global_step/sec: 41.7495
# INFO:tensorflow:loss = 0.618052, step = 16201 (2.395 sec)
# INFO:tensorflow:global_step/sec: 41.7447
# INFO:tensorflow:loss = 0.335689, step = 16301 (2.396 sec)
# INFO:tensorflow:global_step/sec: 41.7248
# INFO:tensorflow:loss = 0.513517, step = 16401 (2.396 sec)
# INFO:tensorflow:global_step/sec: 41.7886
# INFO:tensorflow:loss = 0.483954, step = 16501 (2.393 sec)
# INFO:tensorflow:global_step/sec: 41.8309
# INFO:tensorflow:loss = 0.796042, step = 16601 (2.390 sec)
# INFO:tensorflow:global_step/sec: 41.6518
# INFO:tensorflow:loss = 0.576366, step = 16701 (2.401 sec)
# INFO:tensorflow:global_step/sec: 41.6816
# INFO:tensorflow:loss = 0.658288, step = 16801 (2.399 sec)
# INFO:tensorflow:global_step/sec: 41.8185
# INFO:tensorflow:loss = 0.499374, step = 16901 (2.392 sec)
# INFO:tensorflow:global_step/sec: 41.8501
# INFO:tensorflow:loss = 0.458658, step = 17001 (2.389 sec)
# INFO:tensorflow:global_step/sec: 41.8859
# INFO:tensorflow:loss = 0.499011, step = 17101 (2.387 sec)
# INFO:tensorflow:global_step/sec: 41.7752
# INFO:tensorflow:loss = 0.546397, step = 17201 (2.394 sec)
# INFO:tensorflow:global_step/sec: 41.7254
# INFO:tensorflow:loss = 0.498208, step = 17301 (2.397 sec)
# INFO:tensorflow:global_step/sec: 41.6756
# INFO:tensorflow:loss = 0.527332, step = 17401 (2.399 sec)
# INFO:tensorflow:global_step/sec: 41.6878
# INFO:tensorflow:loss = 0.42867, step = 17501 (2.399 sec)
# INFO:tensorflow:global_step/sec: 41.7427
# INFO:tensorflow:loss = 0.573224, step = 17601 (2.396 sec)
# INFO:tensorflow:global_step/sec: 41.7383
# INFO:tensorflow:loss = 0.65327, step = 17701 (2.396 sec)
# INFO:tensorflow:global_step/sec: 41.6991
# INFO:tensorflow:loss = 0.440424, step = 17801 (2.398 sec)
# INFO:tensorflow:global_step/sec: 41.6813
# INFO:tensorflow:loss = 0.730706, step = 17901 (2.399 sec)
# INFO:tensorflow:global_step/sec: 41.7762
# INFO:tensorflow:loss = 0.577482, step = 18001 (2.393 sec)
# INFO:tensorflow:global_step/sec: 41.7222
# INFO:tensorflow:loss = 0.290761, step = 18101 (2.397 sec)
# INFO:tensorflow:global_step/sec: 41.6648
# INFO:tensorflow:loss = 0.414855, step = 18201 (2.400 sec)
# INFO:tensorflow:global_step/sec: 41.7171
# INFO:tensorflow:loss = 0.409772, step = 18301 (2.397 sec)
# INFO:tensorflow:global_step/sec: 41.6694
# INFO:tensorflow:loss = 0.497723, step = 18401 (2.400 sec)
# INFO:tensorflow:global_step/sec: 41.6783
# INFO:tensorflow:loss = 0.470276, step = 18501 (2.399 sec)
# INFO:tensorflow:global_step/sec: 41.8298
# INFO:tensorflow:loss = 0.431233, step = 18601 (2.391 sec)
# INFO:tensorflow:global_step/sec: 41.6935
# INFO:tensorflow:loss = 0.465872, step = 18701 (2.398 sec)
# INFO:tensorflow:global_step/sec: 41.6787
# INFO:tensorflow:loss = 0.405743, step = 18801 (2.399 sec)
# INFO:tensorflow:global_step/sec: 41.7112
# INFO:tensorflow:loss = 0.396446, step = 18901 (2.397 sec)
# INFO:tensorflow:global_step/sec: 41.7409
# INFO:tensorflow:loss = 0.470949, step = 19001 (2.396 sec)
# INFO:tensorflow:global_step/sec: 41.7841
# INFO:tensorflow:loss = 0.331377, step = 19101 (2.393 sec)
# INFO:tensorflow:global_step/sec: 41.7978
# INFO:tensorflow:loss = 0.410188, step = 19201 (2.392 sec)
# INFO:tensorflow:global_step/sec: 41.6732
# INFO:tensorflow:loss = 0.428039, step = 19301 (2.400 sec)
# INFO:tensorflow:global_step/sec: 41.7669
# INFO:tensorflow:loss = 0.480977, step = 19401 (2.394 sec)
# INFO:tensorflow:global_step/sec: 41.7661
# INFO:tensorflow:loss = 0.394626, step = 19501 (2.394 sec)
# INFO:tensorflow:global_step/sec: 41.7843
# INFO:tensorflow:loss = 0.476923, step = 19601 (2.393 sec)
# INFO:tensorflow:global_step/sec: 41.7821
# INFO:tensorflow:loss = 0.290319, step = 19701 (2.394 sec)
# INFO:tensorflow:global_step/sec: 41.7414
# INFO:tensorflow:loss = 0.304725, step = 19801 (2.395 sec)
# INFO:tensorflow:global_step/sec: 41.7961
# INFO:tensorflow:loss = 0.36377, step = 19901 (2.393 sec)
# INFO:tensorflow:global_step/sec: 41.8248
# INFO:tensorflow:loss = 0.306628, step = 20001 (2.391 sec)
# INFO:tensorflow:global_step/sec: 41.7833
# INFO:tensorflow:loss = 0.486312, step = 20101 (2.393 sec)
# INFO:tensorflow:global_step/sec: 41.8097
# INFO:tensorflow:loss = 0.494632, step = 20201 (2.392 sec)
# INFO:tensorflow:global_step/sec: 41.8105
# INFO:tensorflow:loss = 0.397389, step = 20301 (2.392 sec)
# INFO:tensorflow:global_step/sec: 41.8277
# INFO:tensorflow:loss = 0.359474, step = 20401 (2.391 sec)
# INFO:tensorflow:global_step/sec: 41.7564
# INFO:tensorflow:loss = 0.394591, step = 20501 (2.395 sec)
# INFO:tensorflow:global_step/sec: 41.6697
# INFO:tensorflow:loss = 0.476182, step = 20601 (2.400 sec)
# INFO:tensorflow:global_step/sec: 41.7042
# INFO:tensorflow:loss = 0.406215, step = 20701 (2.398 sec)
# INFO:tensorflow:global_step/sec: 41.6673
# INFO:tensorflow:loss = 0.329873, step = 20801 (2.400 sec)
# INFO:tensorflow:global_step/sec: 41.7211
# INFO:tensorflow:loss = 0.38506, step = 20901 (2.397 sec)
# INFO:tensorflow:global_step/sec: 41.8203
# INFO:tensorflow:loss = 0.507992, step = 21001 (2.391 sec)
# INFO:tensorflow:global_step/sec: 41.7762
# INFO:tensorflow:loss = 0.418083, step = 21101 (2.393 sec)
# INFO:tensorflow:global_step/sec: 41.715
# INFO:tensorflow:loss = 0.331788, step = 21201 (2.397 sec)
# INFO:tensorflow:global_step/sec: 41.7813
# INFO:tensorflow:loss = 0.380274, step = 21301 (2.393 sec)
# INFO:tensorflow:global_step/sec: 41.8686
# INFO:tensorflow:loss = 0.458697, step = 21401 (2.388 sec)
# INFO:tensorflow:global_step/sec: 41.8873
# INFO:tensorflow:loss = 0.369241, step = 21501 (2.387 sec)
# INFO:tensorflow:global_step/sec: 41.6892
# INFO:tensorflow:loss = 0.345255, step = 21601 (2.399 sec)
# INFO:tensorflow:global_step/sec: 41.7273
# INFO:tensorflow:loss = 0.459039, step = 21701 (2.396 sec)
# INFO:tensorflow:global_step/sec: 41.7821
# INFO:tensorflow:loss = 0.222321, step = 21801 (2.394 sec)
# INFO:tensorflow:global_step/sec: 41.6969
# INFO:tensorflow:loss = 0.387038, step = 21901 (2.398 sec)
# INFO:tensorflow:global_step/sec: 41.753
# INFO:tensorflow:loss = 0.408577, step = 22001 (2.395 sec)
# INFO:tensorflow:global_step/sec: 41.7291
# INFO:tensorflow:loss = 0.457462, step = 22101 (2.396 sec)
# INFO:tensorflow:global_step/sec: 41.6917
# INFO:tensorflow:loss = 0.485027, step = 22201 (2.399 sec)
# INFO:tensorflow:global_step/sec: 41.7864
# INFO:tensorflow:loss = 0.316327, step = 22301 (2.393 sec)
# INFO:tensorflow:global_step/sec: 41.8623
# INFO:tensorflow:loss = 0.490506, step = 22401 (2.389 sec)
# INFO:tensorflow:global_step/sec: 41.7648
# INFO:tensorflow:loss = 0.374406, step = 22501 (2.394 sec)
# INFO:tensorflow:global_step/sec: 41.727
# INFO:tensorflow:loss = 0.441987, step = 22601 (2.397 sec)
# INFO:tensorflow:global_step/sec: 41.6963
# INFO:tensorflow:loss = 0.252801, step = 22701 (2.398 sec)
# INFO:tensorflow:global_step/sec: 41.7126
# INFO:tensorflow:loss = 0.39484, step = 22801 (2.397 sec)
# INFO:tensorflow:global_step/sec: 41.737
# INFO:tensorflow:loss = 0.35839, step = 22901 (2.396 sec)
# INFO:tensorflow:global_step/sec: 41.7681
# INFO:tensorflow:loss = 0.475088, step = 23001 (2.395 sec)
# INFO:tensorflow:global_step/sec: 41.7151
# INFO:tensorflow:loss = 0.477071, step = 23101 (2.397 sec)
# INFO:tensorflow:global_step/sec: 41.6966
# INFO:tensorflow:loss = 0.382267, step = 23201 (2.398 sec)
# INFO:tensorflow:global_step/sec: 41.6742
# INFO:tensorflow:loss = 0.377535, step = 23301 (2.400 sec)
# INFO:tensorflow:global_step/sec: 41.7909
# INFO:tensorflow:loss = 0.218033, step = 23401 (2.393 sec)
# INFO:tensorflow:global_step/sec: 41.7555
# INFO:tensorflow:loss = 0.490227, step = 23501 (2.395 sec)
# INFO:tensorflow:global_step/sec: 41.8105
# INFO:tensorflow:loss = 0.33897, step = 23601 (2.392 sec)
# INFO:tensorflow:global_step/sec: 41.715
# INFO:tensorflow:loss = 0.385544, step = 23701 (2.397 sec)
# INFO:tensorflow:global_step/sec: 41.8278
# INFO:tensorflow:loss = 0.319161, step = 23801 (2.391 sec)
# INFO:tensorflow:global_step/sec: 41.7287
# INFO:tensorflow:loss = 0.3733, step = 23901 (2.397 sec)
# INFO:tensorflow:global_step/sec: 41.8149
# INFO:tensorflow:loss = 0.48714, step = 24001 (2.391 sec)
# INFO:tensorflow:global_step/sec: 41.7384
# INFO:tensorflow:loss = 0.412132, step = 24101 (2.396 sec)
# INFO:tensorflow:global_step/sec: 41.7353
# INFO:tensorflow:loss = 0.372364, step = 24201 (2.396 sec)
# INFO:tensorflow:global_step/sec: 41.7232
# INFO:tensorflow:loss = 0.442347, step = 24301 (2.397 sec)
# INFO:tensorflow:global_step/sec: 41.709
# INFO:tensorflow:loss = 0.409337, step = 24401 (2.398 sec)
# INFO:tensorflow:global_step/sec: 41.6714
# INFO:tensorflow:loss = 0.261408, step = 24501 (2.400 sec)
# INFO:tensorflow:global_step/sec: 41.7561
# INFO:tensorflow:loss = 0.507096, step = 24601 (2.395 sec)
# INFO:tensorflow:global_step/sec: 41.7627
# INFO:tensorflow:loss = 0.321186, step = 24701 (2.394 sec)
# INFO:tensorflow:global_step/sec: 41.8159
# INFO:tensorflow:loss = 0.236809, step = 24801 (2.391 sec)
# INFO:tensorflow:global_step/sec: 41.7528
# INFO:tensorflow:loss = 0.434995, step = 24901 (2.395 sec)
# INFO:tensorflow:global_step/sec: 41.7166
# INFO:tensorflow:loss = 0.339999, step = 25001 (2.397 sec)
# INFO:tensorflow:Saving checkpoints for 25041 into /tmp/new_best_1/model.ckpt.
# INFO:tensorflow:global_step/sec: 40.1752
# INFO:tensorflow:loss = 0.30828, step = 25101 (2.489 sec)
# INFO:tensorflow:global_step/sec: 41.7213
# INFO:tensorflow:loss = 0.497445, step = 25201 (2.397 sec)
# INFO:tensorflow:global_step/sec: 41.8034
# INFO:tensorflow:loss = 0.338056, step = 25301 (2.392 sec)
# INFO:tensorflow:global_step/sec: 41.7671
# INFO:tensorflow:loss = 0.252679, step = 25401 (2.394 sec)
# INFO:tensorflow:global_step/sec: 41.7733
# INFO:tensorflow:loss = 0.374873, step = 25501 (2.394 sec)
# INFO:tensorflow:global_step/sec: 41.7219
# INFO:tensorflow:loss = 0.30089, step = 25601 (2.397 sec)
# INFO:tensorflow:global_step/sec: 41.7795
# INFO:tensorflow:loss = 0.364056, step = 25701 (2.394 sec)
# INFO:tensorflow:global_step/sec: 41.7771
# INFO:tensorflow:loss = 0.343968, step = 25801 (2.394 sec)
# INFO:tensorflow:global_step/sec: 41.789
# INFO:tensorflow:loss = 0.431202, step = 25901 (2.393 sec)
# INFO:tensorflow:global_step/sec: 41.7849
# INFO:tensorflow:loss = 0.445296, step = 26001 (2.393 sec)
# INFO:tensorflow:global_step/sec: 41.6738
# INFO:tensorflow:loss = 0.240888, step = 26101 (2.400 sec)
# INFO:tensorflow:global_step/sec: 41.7713
# INFO:tensorflow:loss = 0.363704, step = 26201 (2.394 sec)
# INFO:tensorflow:global_step/sec: 41.8228
# INFO:tensorflow:loss = 0.303009, step = 26301 (2.391 sec)
# INFO:tensorflow:global_step/sec: 41.6247
# INFO:tensorflow:loss = 0.219601, step = 26401 (2.402 sec)
# INFO:tensorflow:global_step/sec: 41.6941
# INFO:tensorflow:loss = 0.254101, step = 26501 (2.399 sec)
# INFO:tensorflow:global_step/sec: 41.8087
# INFO:tensorflow:loss = 0.197488, step = 26601 (2.392 sec)
# INFO:tensorflow:global_step/sec: 41.7789
# INFO:tensorflow:loss = 0.260237, step = 26701 (2.394 sec)
# INFO:tensorflow:global_step/sec: 41.6803
# INFO:tensorflow:loss = 0.288451, step = 26801 (2.399 sec)
# INFO:tensorflow:global_step/sec: 41.7238
# INFO:tensorflow:loss = 0.296147, step = 26901 (2.397 sec)
# INFO:tensorflow:global_step/sec: 41.7229
# INFO:tensorflow:loss = 0.37479, step = 27001 (2.397 sec)
# INFO:tensorflow:global_step/sec: 41.7568
# INFO:tensorflow:loss = 0.311338, step = 27101 (2.395 sec)
# INFO:tensorflow:global_step/sec: 41.7523
# INFO:tensorflow:loss = 0.391277, step = 27201 (2.395 sec)
# INFO:tensorflow:global_step/sec: 41.7439
# INFO:tensorflow:loss = 0.320711, step = 27301 (2.396 sec)
# INFO:tensorflow:global_step/sec: 41.7342
# INFO:tensorflow:loss = 0.199159, step = 27401 (2.396 sec)
# INFO:tensorflow:global_step/sec: 41.7421
# INFO:tensorflow:loss = 0.238845, step = 27501 (2.396 sec)
# INFO:tensorflow:global_step/sec: 41.7401
# INFO:tensorflow:loss = 0.237611, step = 27601 (2.396 sec)
# INFO:tensorflow:global_step/sec: 41.712
# INFO:tensorflow:loss = 0.167268, step = 27701 (2.397 sec)
# INFO:tensorflow:global_step/sec: 41.7814
# INFO:tensorflow:loss = 0.235328, step = 27801 (2.394 sec)
# INFO:tensorflow:global_step/sec: 41.6075
# INFO:tensorflow:loss = 0.372672, step = 27901 (2.403 sec)
# INFO:tensorflow:global_step/sec: 41.6163
# INFO:tensorflow:loss = 0.314186, step = 28001 (2.403 sec)
# INFO:tensorflow:global_step/sec: 41.7075
# INFO:tensorflow:loss = 0.29076, step = 28101 (2.398 sec)
# INFO:tensorflow:global_step/sec: 41.7433
# INFO:tensorflow:loss = 0.26016, step = 28201 (2.396 sec)
# INFO:tensorflow:global_step/sec: 41.7905
# INFO:tensorflow:loss = 0.333007, step = 28301 (2.393 sec)
# INFO:tensorflow:global_step/sec: 41.6916
# INFO:tensorflow:loss = 0.20716, step = 28401 (2.399 sec)
# INFO:tensorflow:global_step/sec: 41.7168
# INFO:tensorflow:loss = 0.334012, step = 28501 (2.397 sec)
# INFO:tensorflow:global_step/sec: 41.7032
# INFO:tensorflow:loss = 0.156907, step = 28601 (2.398 sec)
# INFO:tensorflow:global_step/sec: 41.8311
# INFO:tensorflow:loss = 0.285547, step = 28701 (2.391 sec)
# INFO:tensorflow:global_step/sec: 41.7397
# INFO:tensorflow:loss = 0.252282, step = 28801 (2.396 sec)
# INFO:tensorflow:global_step/sec: 41.6452
# INFO:tensorflow:loss = 0.290225, step = 28901 (2.401 sec)
# INFO:tensorflow:global_step/sec: 41.6895
# INFO:tensorflow:loss = 0.26102, step = 29001 (2.399 sec)
# INFO:tensorflow:global_step/sec: 41.7272
# INFO:tensorflow:loss = 0.413013, step = 29101 (2.397 sec)
# INFO:tensorflow:global_step/sec: 41.7848
# INFO:tensorflow:loss = 0.310203, step = 29201 (2.393 sec)
# INFO:tensorflow:global_step/sec: 41.661
# INFO:tensorflow:loss = 0.121901, step = 29301 (2.400 sec)
# INFO:tensorflow:global_step/sec: 41.7632
# INFO:tensorflow:loss = 0.218847, step = 29401 (2.395 sec)
# INFO:tensorflow:global_step/sec: 41.7205
# INFO:tensorflow:loss = 0.17147, step = 29501 (2.397 sec)
# INFO:tensorflow:global_step/sec: 41.8021
# INFO:tensorflow:loss = 0.176402, step = 29601 (2.392 sec)
# INFO:tensorflow:global_step/sec: 41.6926
# INFO:tensorflow:loss = 0.217832, step = 29701 (2.398 sec)
# INFO:tensorflow:global_step/sec: 41.7734
# INFO:tensorflow:loss = 0.223638, step = 29801 (2.394 sec)
# INFO:tensorflow:global_step/sec: 41.7775
# INFO:tensorflow:loss = 0.282602, step = 29901 (2.394 sec)
# INFO:tensorflow:global_step/sec: 41.723
# INFO:tensorflow:loss = 0.386418, step = 30001 (2.396 sec)
# INFO:tensorflow:global_step/sec: 41.7372
# INFO:tensorflow:loss = 0.177352, step = 30101 (2.396 sec)
# INFO:tensorflow:global_step/sec: 41.6733
# INFO:tensorflow:loss = 0.242614, step = 30201 (2.400 sec)
# INFO:tensorflow:global_step/sec: 41.741
# INFO:tensorflow:loss = 0.267906, step = 30301 (2.395 sec)
# INFO:tensorflow:global_step/sec: 41.7659
# INFO:tensorflow:loss = 0.318897, step = 30401 (2.395 sec)
# INFO:tensorflow:global_step/sec: 41.6884
# INFO:tensorflow:loss = 0.236978, step = 30501 (2.399 sec)
# INFO:tensorflow:global_step/sec: 41.7788
# INFO:tensorflow:loss = 0.16638, step = 30601 (2.393 sec)
# INFO:tensorflow:global_step/sec: 41.8529
# INFO:tensorflow:loss = 0.352046, step = 30701 (2.389 sec)
# INFO:tensorflow:global_step/sec: 41.7056
# INFO:tensorflow:loss = 0.284976, step = 30801 (2.398 sec)
# INFO:tensorflow:global_step/sec: 41.7564
# INFO:tensorflow:loss = 0.271131, step = 30901 (2.395 sec)
# INFO:tensorflow:global_step/sec: 41.7068
# INFO:tensorflow:loss = 0.197483, step = 31001 (2.397 sec)
# INFO:tensorflow:global_step/sec: 41.7192
# INFO:tensorflow:loss = 0.228762, step = 31101 (2.397 sec)
# INFO:tensorflow:global_step/sec: 41.7025
# INFO:tensorflow:loss = 0.189903, step = 31201 (2.398 sec)
# INFO:tensorflow:global_step/sec: 41.783
# INFO:tensorflow:loss = 0.257247, step = 31301 (2.393 sec)
# INFO:tensorflow:global_step/sec: 41.7236
# INFO:tensorflow:loss = 0.206184, step = 31401 (2.397 sec)
# INFO:tensorflow:global_step/sec: 41.753
# INFO:tensorflow:loss = 0.196063, step = 31501 (2.395 sec)
# INFO:tensorflow:global_step/sec: 41.613
# INFO:tensorflow:loss = 0.261977, step = 31601 (2.403 sec)
# INFO:tensorflow:global_step/sec: 41.6576
# INFO:tensorflow:loss = 0.192513, step = 31701 (2.401 sec)
# INFO:tensorflow:global_step/sec: 41.6919
# INFO:tensorflow:loss = 0.231794, step = 31801 (2.399 sec)
# INFO:tensorflow:global_step/sec: 41.8058
# INFO:tensorflow:loss = 0.214766, step = 31901 (2.392 sec)
# INFO:tensorflow:global_step/sec: 41.7507
# INFO:tensorflow:loss = 0.199423, step = 32001 (2.395 sec)
# INFO:tensorflow:global_step/sec: 41.7175
# INFO:tensorflow:loss = 0.250342, step = 32101 (2.397 sec)
# INFO:tensorflow:global_step/sec: 41.6372
# INFO:tensorflow:loss = 0.259, step = 32201 (2.402 sec)
# INFO:tensorflow:global_step/sec: 41.7385
# INFO:tensorflow:loss = 0.42157, step = 32301 (2.396 sec)
# INFO:tensorflow:global_step/sec: 41.815
# INFO:tensorflow:loss = 0.194077, step = 32401 (2.392 sec)
# INFO:tensorflow:global_step/sec: 41.7689
# INFO:tensorflow:loss = 0.302018, step = 32501 (2.394 sec)
# INFO:tensorflow:global_step/sec: 41.7122
# INFO:tensorflow:loss = 0.180023, step = 32601 (2.397 sec)
# INFO:tensorflow:global_step/sec: 41.7058
# INFO:tensorflow:loss = 0.157555, step = 32701 (2.398 sec)
# INFO:tensorflow:global_step/sec: 41.6117
# INFO:tensorflow:loss = 0.170432, step = 32801 (2.403 sec)
# INFO:tensorflow:global_step/sec: 41.7289
# INFO:tensorflow:loss = 0.178296, step = 32901 (2.396 sec)
# INFO:tensorflow:global_step/sec: 41.655
# INFO:tensorflow:loss = 0.195416, step = 33001 (2.401 sec)
# INFO:tensorflow:global_step/sec: 41.7794
# INFO:tensorflow:loss = 0.302663, step = 33101 (2.394 sec)
# INFO:tensorflow:global_step/sec: 41.7476
# INFO:tensorflow:loss = 0.341661, step = 33201 (2.395 sec)
# INFO:tensorflow:global_step/sec: 41.7089
# INFO:tensorflow:loss = 0.22212, step = 33301 (2.398 sec)
# INFO:tensorflow:global_step/sec: 41.7093
# INFO:tensorflow:loss = 0.183975, step = 33401 (2.397 sec)
# INFO:tensorflow:global_step/sec: 41.7882
# INFO:tensorflow:loss = 0.152023, step = 33501 (2.393 sec)
# INFO:tensorflow:global_step/sec: 41.711
# INFO:tensorflow:loss = 0.302771, step = 33601 (2.397 sec)
# INFO:tensorflow:global_step/sec: 41.6601
# INFO:tensorflow:loss = 0.199815, step = 33701 (2.400 sec)
# INFO:tensorflow:global_step/sec: 41.7627
# INFO:tensorflow:loss = 0.200435, step = 33801 (2.394 sec)
# INFO:tensorflow:global_step/sec: 41.6765
# INFO:tensorflow:loss = 0.255432, step = 33901 (2.400 sec)
# INFO:tensorflow:global_step/sec: 41.7071
# INFO:tensorflow:loss = 0.172435, step = 34001 (2.398 sec)
# INFO:tensorflow:global_step/sec: 41.7297
# INFO:tensorflow:loss = 0.262163, step = 34101 (2.396 sec)
# INFO:tensorflow:global_step/sec: 41.7591
# INFO:tensorflow:loss = 0.170383, step = 34201 (2.395 sec)
# INFO:tensorflow:global_step/sec: 41.7386
# INFO:tensorflow:loss = 0.241954, step = 34301 (2.395 sec)
# INFO:tensorflow:global_step/sec: 41.2416
# INFO:tensorflow:loss = 0.177837, step = 34401 (2.425 sec)
# INFO:tensorflow:global_step/sec: 41.6325
# INFO:tensorflow:loss = 0.250727, step = 34501 (2.401 sec)
# INFO:tensorflow:global_step/sec: 41.8158
# INFO:tensorflow:loss = 0.194766, step = 34601 (2.391 sec)
# INFO:tensorflow:global_step/sec: 41.6999
# INFO:tensorflow:loss = 0.149464, step = 34701 (2.398 sec)
# INFO:tensorflow:global_step/sec: 41.684
# INFO:tensorflow:loss = 0.200906, step = 34801 (2.399 sec)
# INFO:tensorflow:global_step/sec: 41.6967
# INFO:tensorflow:loss = 0.19918, step = 34901 (2.398 sec)
# INFO:tensorflow:global_step/sec: 41.6685
# INFO:tensorflow:loss = 0.180595, step = 35001 (2.400 sec)
# INFO:tensorflow:global_step/sec: 41.7111
# INFO:tensorflow:loss = 0.162303, step = 35101 (2.397 sec)
# INFO:tensorflow:global_step/sec: 41.7443
# INFO:tensorflow:loss = 0.203554, step = 35201 (2.395 sec)
# INFO:tensorflow:global_step/sec: 41.8111
# INFO:tensorflow:loss = 0.296849, step = 35301 (2.392 sec)
# INFO:tensorflow:global_step/sec: 41.7484
# INFO:tensorflow:loss = 0.281488, step = 35401 (2.395 sec)
# INFO:tensorflow:global_step/sec: 41.7812
# INFO:tensorflow:loss = 0.163063, step = 35501 (2.393 sec)
# INFO:tensorflow:global_step/sec: 41.7885
# INFO:tensorflow:loss = 0.180037, step = 35601 (2.394 sec)
# INFO:tensorflow:global_step/sec: 41.6967
# INFO:tensorflow:loss = 0.284735, step = 35701 (2.398 sec)
# INFO:tensorflow:global_step/sec: 41.7472
# INFO:tensorflow:loss = 0.286777, step = 35801 (2.396 sec)
# INFO:tensorflow:global_step/sec: 41.6507
# INFO:tensorflow:loss = 0.232861, step = 35901 (2.401 sec)
# INFO:tensorflow:global_step/sec: 41.7513
# INFO:tensorflow:loss = 0.131342, step = 36001 (2.395 sec)
# INFO:tensorflow:global_step/sec: 41.7394
# INFO:tensorflow:loss = 0.250593, step = 36101 (2.396 sec)
# INFO:tensorflow:global_step/sec: 41.7837
# INFO:tensorflow:loss = 0.182206, step = 36201 (2.393 sec)
# INFO:tensorflow:global_step/sec: 41.7978
# INFO:tensorflow:loss = 0.148944, step = 36301 (2.393 sec)
# INFO:tensorflow:global_step/sec: 41.7905
# INFO:tensorflow:loss = 0.170955, step = 36401 (2.392 sec)
# INFO:tensorflow:global_step/sec: 41.8307
# INFO:tensorflow:loss = 0.163362, step = 36501 (2.391 sec)
# INFO:tensorflow:global_step/sec: 41.7158
# INFO:tensorflow:loss = 0.141845, step = 36601 (2.397 sec)
# INFO:tensorflow:global_step/sec: 41.7288
# INFO:tensorflow:loss = 0.145817, step = 36701 (2.397 sec)
# INFO:tensorflow:global_step/sec: 41.6827
# INFO:tensorflow:loss = 0.19006, step = 36801 (2.399 sec)
# INFO:tensorflow:global_step/sec: 41.6391
# INFO:tensorflow:loss = 0.261151, step = 36901 (2.401 sec)
# INFO:tensorflow:global_step/sec: 41.8143
# INFO:tensorflow:loss = 0.123734, step = 37001 (2.391 sec)
# INFO:tensorflow:global_step/sec: 41.7812
# INFO:tensorflow:loss = 0.208829, step = 37101 (2.394 sec)
# INFO:tensorflow:global_step/sec: 41.6667
# INFO:tensorflow:loss = 0.149918, step = 37201 (2.400 sec)
# INFO:tensorflow:global_step/sec: 41.7059
# INFO:tensorflow:loss = 0.189367, step = 37301 (2.398 sec)
# INFO:tensorflow:global_step/sec: 41.8207
# INFO:tensorflow:loss = 0.109398, step = 37401 (2.391 sec)
# INFO:tensorflow:global_step/sec: 41.7026
# INFO:tensorflow:loss = 0.110053, step = 37501 (2.398 sec)
# INFO:tensorflow:global_step/sec: 41.743
# INFO:tensorflow:loss = 0.194481, step = 37601 (2.395 sec)
# INFO:tensorflow:global_step/sec: 41.5862
# INFO:tensorflow:loss = 0.149512, step = 37701 (2.405 sec)
# INFO:tensorflow:global_step/sec: 41.6503
# INFO:tensorflow:loss = 0.124879, step = 37801 (2.401 sec)
# INFO:tensorflow:global_step/sec: 41.7252
# INFO:tensorflow:loss = 0.128173, step = 37901 (2.396 sec)
# INFO:tensorflow:global_step/sec: 41.8013
# INFO:tensorflow:loss = 0.164393, step = 38001 (2.392 sec)
# INFO:tensorflow:global_step/sec: 41.7672
# INFO:tensorflow:loss = 0.145203, step = 38101 (2.394 sec)
# INFO:tensorflow:global_step/sec: 41.6834
# INFO:tensorflow:loss = 0.153652, step = 38201 (2.399 sec)
# INFO:tensorflow:global_step/sec: 41.6839
# INFO:tensorflow:loss = 0.181473, step = 38301 (2.399 sec)
# INFO:tensorflow:global_step/sec: 41.7851
# INFO:tensorflow:loss = 0.120822, step = 38401 (2.394 sec)
# INFO:tensorflow:global_step/sec: 41.7611
# INFO:tensorflow:loss = 0.12705, step = 38501 (2.394 sec)
# INFO:tensorflow:global_step/sec: 41.649
# INFO:tensorflow:loss = 0.142926, step = 38601 (2.401 sec)
# INFO:tensorflow:global_step/sec: 41.819
# INFO:tensorflow:loss = 0.199803, step = 38701 (2.391 sec)
# INFO:tensorflow:global_step/sec: 41.8575
# INFO:tensorflow:loss = 0.119649, step = 38801 (2.389 sec)
# INFO:tensorflow:global_step/sec: 41.7149
# INFO:tensorflow:loss = 0.144599, step = 38901 (2.397 sec)
# INFO:tensorflow:global_step/sec: 41.6453
# INFO:tensorflow:loss = 0.184549, step = 39001 (2.401 sec)
# INFO:tensorflow:global_step/sec: 41.7767
# INFO:tensorflow:loss = 0.191966, step = 39101 (2.394 sec)
# INFO:tensorflow:global_step/sec: 41.74
# INFO:tensorflow:loss = 0.0920218, step = 39201 (2.396 sec)
# INFO:tensorflow:global_step/sec: 41.6964
# INFO:tensorflow:loss = 0.216886, step = 39301 (2.398 sec)
# INFO:tensorflow:global_step/sec: 41.8277
# INFO:tensorflow:loss = 0.121958, step = 39401 (2.391 sec)
# INFO:tensorflow:global_step/sec: 41.6991
# INFO:tensorflow:loss = 0.0875329, step = 39501 (2.398 sec)
# INFO:tensorflow:global_step/sec: 41.7035
# INFO:tensorflow:loss = 0.0794018, step = 39601 (2.398 sec)
# INFO:tensorflow:global_step/sec: 41.6797
# INFO:tensorflow:loss = 0.104248, step = 39701 (2.399 sec)
# INFO:tensorflow:global_step/sec: 41.7337
# INFO:tensorflow:loss = 0.168345, step = 39801 (2.396 sec)
# INFO:tensorflow:global_step/sec: 41.7773
# INFO:tensorflow:loss = 0.114157, step = 39901 (2.394 sec)
# INFO:tensorflow:Saving checkpoints for 40000 into /tmp/new_best_1/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.0943438.

# %%
# Evaluate the model and print results (training accuracy)
eval_input_fn = tf.estimator.inputs.numpy_input_fn(
    x={"x": X_train},
    y=y_train,
    num_epochs=1,
    shuffle=False)
eval_results = my_classifier.evaluate(input_fn=eval_input_fn)
print(eval_results)
# Out:
# WARNING:tensorflow:VARIABLES collection name is deprecated, please use GLOBAL_VARIABLES instead; VARIABLES will be removed after 2017-03-02.
# WARNING:tensorflow:VARIABLES collection name is deprecated, please use GLOBAL_VARIABLES instead; VARIABLES will be removed after 2017-03-02.
# [None, 16, 16, 64]
# [None, 8, 8, 64]
# WARNING:tensorflow:VARIABLES collection name is deprecated, please use GLOBAL_VARIABLES instead; VARIABLES will be removed after 2017-03-02.
# WARNING:tensorflow:VARIABLES collection name is deprecated, please use GLOBAL_VARIABLES instead; VARIABLES will be removed after 2017-03-02.
# INFO:tensorflow:Starting evaluation at 2017-10-31-03:17:08
# INFO:tensorflow:Restoring parameters from /tmp/new_best_1/model.ckpt-40000
# INFO:tensorflow:Finished evaluation at 2017-10-31-03:17:11
# INFO:tensorflow:Saving dict for global step 40000: accuracy = 0.992044, global_step = 40000, loss = 0.161719
# {'loss': 0.16171852, 'global_step': 40000, 'accuracy': 0.99204445}

# %%
# Evaluate the model and print results (validation accuracy)
print(X_validation.shape)
print(y_validation.shape)
eval_input_fn = tf.estimator.inputs.numpy_input_fn(
    x={"x": X_validation},
    y=y_validation,
    num_epochs=1,
    shuffle=False)
eval_results = my_classifier.evaluate(input_fn=eval_input_fn)
print(eval_results)
# Out:
# (5000, 3072)
# (5000,)
# WARNING:tensorflow:VARIABLES collection name is deprecated, please use GLOBAL_VARIABLES instead; VARIABLES will be removed after 2017-03-02.
# WARNING:tensorflow:VARIABLES collection name is deprecated, please use GLOBAL_VARIABLES instead; VARIABLES will be removed after 2017-03-02.
# [None, 16, 16, 64]
# [None, 8, 8, 64]
# WARNING:tensorflow:VARIABLES collection name is deprecated, please use GLOBAL_VARIABLES instead; VARIABLES will be removed after 2017-03-02.
# WARNING:tensorflow:VARIABLES collection name is deprecated, please use GLOBAL_VARIABLES instead; VARIABLES will be removed after 2017-03-02.
# INFO:tensorflow:Starting evaluation at 2017-10-31-03:17:18
# INFO:tensorflow:Restoring parameters from /tmp/new_best_1/model.ckpt-40000
# INFO:tensorflow:Finished evaluation at 2017-10-31-03:17:19
# INFO:tensorflow:Saving dict for global step 40000: accuracy = 0.7844, global_step = 40000, loss = 0.63676
# {'loss': 0.63675976, 'global_step': 40000, 'accuracy': 0.78439999}

# %%
# Part 1: 72.74%
# With AdaOptizer, 3 layers, dropout after each layer, 3x3 kernel size: 78.08%

# %%
#Run model on test data and output .npy corresponding to last layer
X_test = np.transpose(X_test_orig).astype("float32")
eval_input_fn = tf.estimator.inputs.numpy_input_fn(
    x={"x": X_test},
    num_epochs=1,
    shuffle=False)
predict_results = list(my_classifier.predict(input_fn=eval_input_fn))
predict_results = np.transpose(np.array(predict_results))
print(predict_results.shape)
np.save('save_result_deepnetwork', predict_results)
print(predict_results[:][:10])
# Out:
# WARNING:tensorflow:VARIABLES collection name is deprecated, please use GLOBAL_VARIABLES instead; VARIABLES will be removed after 2017-03-02.
# WARNING:tensorflow:VARIABLES collection name is deprecated, please use GLOBAL_VARIABLES instead; VARIABLES will be removed after 2017-03-02.
# [None, 16, 16, 64]
# [None, 8, 8, 64]
# WARNING:tensorflow:VARIABLES collection name is deprecated, please use GLOBAL_VARIABLES instead; VARIABLES will be removed after 2017-03-02.
# WARNING:tensorflow:VARIABLES collection name is deprecated, please use GLOBAL_VARIABLES instead; VARIABLES will be removed after 2017-03-02.
# INFO:tensorflow:Restoring parameters from /tmp/new_best_1/model.ckpt-40000
# (10, 10000)
# [[  5.62372152e-03   8.76653125e-04   8.04656327e-01 ...,   1.04960964e-04
#     4.64902483e-02   3.37883557e-06]
#  [  6.26017805e-03   2.07057819e-02   1.14419257e-04 ...,   3.48947026e-07
#     2.64663100e-01   2.89091332e-07]
#  [  2.39450228e-03   4.54080691e-06   8.43445063e-02 ...,   7.32759163e-02
#     3.15578133e-02   3.26221023e-04]
#  ...,
#  [  1.13329617e-02   3.74254824e-07   5.49087534e-03 ...,   3.80854867e-03
#     8.98400496e-04   9.70146120e-01]
#  [  3.26065980e-02   9.77846742e-01   2.13371404e-02 ...,   4.04301827e-05
#     1.97346759e-04   3.32854455e-07]
#  [  5.82344830e-03   4.09708533e-04   2.61041248e-04 ...,   3.03022716e-05
#     2.88082490e-04   8.79599725e-07]]
